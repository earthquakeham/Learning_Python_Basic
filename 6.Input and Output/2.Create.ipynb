# %%
# file create @ 상대 위치
file_root = open('write_test.txt', 'w')
file_root.close()    # 열려 있는 객체를 닫아 주는 역할. 생략 가능

# %%
# file create @ 절대 위치
file_root = open('/Users/earthquakeham/Library/Mobile Documents/com~apple~CloudDocs/PYTHON/write_test1.txt', 'w')
file_root.close()    # 열려 있는 객체를 닫아 주는 역할. 생략 가능

# %%
# 생성한 파일에 data 입력
file_root = open('/Users/earthquakeham/Library/Mobile Documents/com~apple~CloudDocs/PYTHON/write_test2.txt', 'w')
for i in range(1,11):
    data = "%d번째 줄입니다. \n" % i
    file_root.write(data)
file_root.close()
