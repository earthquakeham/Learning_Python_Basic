# %%
# a 모드와 w 모드의 차이 비교. 각각 적용 후 파일을 열어보자
# a 모드는 추가하기   /   w 모드는 덮어쓰기
file_root = open('/Users/earthquakeham/Library/Mobile Documents/com~apple~CloudDocs/PYTHON/write_test2.txt', 'a') 
for i in range(11,20):
    data = "%d번째 줄입니다. \n" % i
    file_root.write(data)
file_root.close()
