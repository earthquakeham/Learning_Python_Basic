# %%
# module 사용 방법1
# 동일 root 폴더 내에 있는 "module_sample2.py" 파일 불러오기
import module_sample2
module_sample2.calculation1(4,5)
module_sample2.calculation2("a",5)
# Out:
# Sum : 9, Mul : 20
# a and b are different type!

# %%
# module 사용 방법2
# 동일 root 폴더 내에 있는 "module_sample2.py" 파일 내에서 "calculation1"과 "calculation2" 함수만 불러오기
from module_sample2 import calculation1, calculation2  

calculation1(4,5)
calculation2("a",5)

# %%
# module 사용 방법3
# 동일 root 폴더 내에 있는 "module_sample2.py" 파일 내의 모든 함수 불러오기
from module_sample2 import *
calculation1(4,5)
calculation2("a",5)
